# %% [markdown]
# # Lesson 3 - BOLDgspins
#
# The `BOLDspins` module contains the objects which define Monte Carlo spin diffusion in simulations. To begin we first import the module as follows (and NumPy for array creation):

# %%
from BOLDswimsuite import BOLDgeometry, BOLDspins
import numpy as np
import matplotlib.pyplot as plt
